# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %% [markdown]
# ### Problem 1: Exploratory Analysis
#
# **a) Print the overall statistical description of the data and plot standard statistical distributions for each variable.**

# %%
abalone = pd.read_csv('quizData_SetA.csv')

# %%
abalone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Height    4000 non-null   float64
#  1   Weight    4000 non-null   float64
#  2   Diameter  4000 non-null   float64
#  3   Length    4000 non-null   float64
# dtypes: float64(4)
# memory usage: 125.1 KB

# %%
abalone.describe()
# Out:
#             Height       Weight     Diameter       Length
# count  4000.000000  4000.000000  4000.000000  4000.000000
# mean      0.138874     0.819623     0.406095     0.521759
# std       0.042092     0.489400     0.099668     0.120595
# min       0.000000     0.002000     0.055000     0.075000
# 25%       0.110000     0.433500     0.345000     0.450000
# 50%       0.140000     0.787750     0.420000     0.540000
# 75%       0.165000     1.144500     0.480000     0.615000
# max       1.130000     2.825500     0.650000     0.815000

# %%
# Draw the distributions of all variables
f, axes = plt.subplots(4, 2, figsize=(12, 24))
colors = ["r", "g", "b", "m"]

count = 0
for var in abalone:
    sb.distplot(abalone[var], ax = axes[count,0], color = colors[count])
    sb.violinplot(abalone[var], ax = axes[count,1], color = colors[count])
    count += 1

# %% [markdown]
# **Comment : Which variable has the most “Normal” looking distribution? Which variable has the maximum outliers?**
#
# Length has the most "Normal" looking distribution.
# Height has the maximum outliers

# %% [markdown]
# **b) Print the mutual correlation amongst all the variables using a correlation heatmap.**

# %%
# Heatmap of the Correlation Matrix
f, axes = plt.subplots(1, 1, figsize=(12, 8))
sb.heatmap(abalone.corr(), vmin = -1, vmax = 1, annot = True, fmt = ".2f")

# %% [markdown]
# **Comment : Which variable has the highest absolute correlation with Length? Is such a strong correlation helpful in predicting Length?**
#
# Diameter has the highest absolute correlation with Length (0.99).
# Yes, Length will increase with Diameter, hence Diameter can be used to predict length

# %% [markdown]
# **c) Visualize the relationship amongst Length and the other variables using mutual jointplots and an overall pairplot.**

# %%
#mutual jointplots
colors = ["r", "g", "b"]
count = 0

for var in abalone:
    if var != 'Length':
        sb.jointplot(x = abalone[var], y = abalone['Length'], color = colors[count])
        count += 1

# %%
#pairplot
sb.pairplot(data = abalone)

# %% [markdown]
# **Comment : Which of the variables has the strongest linear relation with Length? Is it useful in prediction?**
#
# Diameter has the strongest linear relation with Length. Yes, it has a strong linearity and can be used to predict Length.

# %% [markdown]
# ### Problem 2 : Uni-Variate Linear Regression
#
# **a) Partition the dataset randomly into Train and Test datasets – 70% for Train and 30% for Test. On the Train set, fit three uni-variate Linear Regression models for Length against each of the three other variables. For each such linear model, print the coefficients of the model you fit, and plot the regression line on a scatterplot.**

# %%
# Import essential models and functions from sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

length = pd.DataFrame(abalone['Length'])
height = pd.DataFrame(abalone['Height'])

a_train, a_test, y_train, y_test= train_test_split(height, length, test_size = 0.3)

# %%
# Create a Linear Regression object
linreg = LinearRegression()

# %% [markdown]
# `Length` against `Height`

# %%
# Train the Linear Regression model
linreg.fit(a_train, y_train)
# Coefficients of the Linear Regression line
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [0.2096576]
# Coefficients 	: a =  [[2.25096644]]

# %%
# Formula for the Regression line
regline_x = a_train
regline_y = linreg.intercept_ + linreg.coef_ * a_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(a_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# `Length` against `Weight`

# %%
weight = pd.DataFrame(abalone['Weight'])
length = pd.DataFrame(abalone['Length'])

b_train, b_test, y_train, y_test= train_test_split(weight, length, test_size = 0.3)

# Train the Linear Regression model
linreg.fit(b_train, y_train)

# Coefficients of the Linear Regression line
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [0.33697235]
# Coefficients 	: a =  [[0.22587964]]

# %%
# Formula for the Regression line
regline_x = b_train
regline_y = linreg.intercept_ + linreg.coef_ * b_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(b_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# `Length` against `Diameter`

# %%
weight = pd.DataFrame(abalone['Diameter'])
length = pd.DataFrame(abalone['Length'])

c_train, c_test, y_train, y_test= train_test_split(weight, length, test_size = 0.3)

# Train the Linear Regression model
linreg.fit(c_train, y_train)

# Coefficients of the Linear Regression line
print('Intercept \t: b = ', linreg.intercept_)
print('Coefficients \t: a = ', linreg.coef_)
# Out:
# Intercept 	: b =  [0.03659263]
# Coefficients 	: a =  [[1.1942465]]

# %%
# Formula for the Regression line
regline_x = c_train
regline_y = linreg.intercept_ + linreg.coef_ * c_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(c_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# %% [markdown]
# **b) Predict Length using each of the three models on both Train and Test datasets. Plot the actual values of Length against the predicted values of Length in each case. Print the Mean Squared Errors and R^2 values in each case.**

# %% [markdown]
# `Length` against `Height`

# %%
length = pd.DataFrame(abalone['Length'])
height = pd.DataFrame(abalone['Height'])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(height, length, test_size = 0.3)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

print("Train dataset:")
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# Predict SalePrice values corresponding to GrLivArea
y_test_pred = linreg.predict(X_test)

print("Test dataset:")
# Plot the Predictions
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [0.21526065]
# Coefficients of Regression 	: a =  [[2.20911158]]
#
# Train dataset:
# Test dataset:
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.6349295973118649
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-4e7748b14412> in <module>
#      38 print("Goodness of Fit of Model \tTrain Dataset")
#      39 print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
# ---> 40 print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
#      41 print()
#      42
#
# NameError: name 'y_train_pred' is not defined

# %% [markdown]
# `Length` against `Weight`

# %%
length = pd.DataFrame(abalone['Length'])
weight = pd.DataFrame(abalone['Weight'])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(weight, length, test_size = 0.3)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

print("Train Dataset:")
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# Predict SalePrice values corresponding to GrLivArea
y_test_pred = linreg.predict(X_test)

print("Test Dataset:")
# Plot the Predictions
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()

# %% [markdown]
# `Length` against `Diameter`

# %%
length = pd.DataFrame(abalone['Length'])
diameter = pd.DataFrame(abalone['Diameter'])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(diameter, length, test_size = 0.3)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

print("Train Dataset:")
# Formula for the Regression line
regline_x = X_train
regline_y = linreg.intercept_ + linreg.coef_ * X_train

# Plot the Linear Regression line
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_train, y_train)
plt.plot(regline_x, regline_y, 'r-', linewidth = 3)
plt.show()

# Predict SalePrice values corresponding to GrLivArea
y_test_pred = linreg.predict(X_test)

print("Test Dataset:")
# Plot the Predictions
f, axes = plt.subplots(1, 1, figsize=(16, 8))
plt.scatter(X_test, y_test, color = "green")
plt.scatter(X_test, y_test_pred, color = "red")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()

# %% [markdown]
# **c) Comment : Which of the three uni-variate linear models is the best in terms of predicting Length? Briefly justify.**
#
# Length against Diameter is the best for predicting length as it has the smallest MSE, and the highest R^2.

# %% [markdown]
# ### Problem 3 : Multi-Variate Linear Regression
#
# a) Partition the dataset randomly into Train and Test datasets – 70% for Train and 30% for Test. On the Train set, fit a single multi-variate Linear Regression model for Length against all of the three other variables.

# %%
# Extract Response and Predictors
y = pd.DataFrame(abalone["Length"])
X = pd.DataFrame(abalone[["Height", "Weight", "Diameter"]])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Print the Coefficients against Predictors
print(pd.DataFrame(list(zip(X_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"]))
print()

# Predict Response corresponding to Predictors
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()

# %% [markdown]
# **b) Predict Length using this model on both Train and Test datasets. Print the Mean Squared Error and R^2 values.**

# %%
y = pd.DataFrame(abalone["Length"])
X = pd.DataFrame(abalone[["Height", "Weight", "Diameter"]])

# Split the Dataset into Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# Linear Regression using Train Data
linreg = LinearRegression()         # create the linear regression object
linreg.fit(X_train, y_train)        # train the linear regression model

# Coefficients of the Linear Regression line
print('Intercept of Regression \t: b = ', linreg.intercept_)
print('Coefficients of Regression \t: a = ', linreg.coef_)
print()

# Print the Coefficients against Predictors
print(pd.DataFrame(list(zip(X_train.columns, linreg.coef_[0])), columns = ["Predictors", "Coefficients"]))
print()

# Predict Response corresponding to Predictors
y_train_pred = linreg.predict(X_train)
y_test_pred = linreg.predict(X_test)

# Plot the Predictions vs the True values
f, axes = plt.subplots(1, 2, figsize=(24, 12))
axes[0].scatter(y_train, y_train_pred, color = "blue")
axes[0].plot(y_train, y_train, 'w-', linewidth = 1)
axes[0].set_xlabel("True values of the Response Variable (Train)")
axes[0].set_ylabel("Predicted values of the Response Variable (Train)")
axes[1].scatter(y_test, y_test_pred, color = "green")
axes[1].plot(y_test, y_test, 'w-', linewidth = 1)
axes[1].set_xlabel("True values of the Response Variable (Test)")
axes[1].set_ylabel("Predicted values of the Response Variable (Test)")
plt.show()

# Check the Goodness of Fit (on Train Data)
print("Goodness of Fit of Model \tTrain Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_train, y_train))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_train, y_train_pred))
print()

# Check the Goodness of Fit (on Test Data)
print("Goodness of Fit of Model \tTest Dataset")
print("Explained Variance (R^2) \t:", linreg.score(X_test, y_test))
print("Mean Squared Error (MSE) \t:", mean_squared_error(y_test, y_test_pred))
print()
# Out:
# Intercept of Regression 	: b =  [0.05682163]
# Coefficients of Regression 	: a =  [[0.01982622 0.01930721 1.09890657]]
#
#   Predictors  Coefficients
# 0     Height      0.019826
# 1     Weight      0.019307
# 2   Diameter      1.098907
# Goodness of Fit of Model 	Train Dataset
# Explained Variance (R^2) 	: 0.9745923239882421
# Mean Squared Error (MSE) 	: 0.00036437746067540015
#
# Goodness of Fit of Model 	Test Dataset
# Explained Variance (R^2) 	: 0.9769353148098521
# Mean Squared Error (MSE) 	: 0.0003489939283417936
